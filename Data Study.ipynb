# %%
from preprocessing import PrepareData
import pandas as pd
import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style()
# Out:
# /home/joannelam/Projects/my_project/lib/python2.7/site-packages/pandas/_libs/__init__.py:3: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .tslib import iNaT, NaT, Timestamp, Timedelta, OutOfBoundsDatetime
# /home/joannelam/Projects/my_project/lib/python2.7/site-packages/pandas/_libs/__init__.py:3: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   from .tslib import iNaT, NaT, Timestamp, Timedelta, OutOfBoundsDatetime
# /home/joannelam/Projects/my_project/lib/python2.7/site-packages/pandas/__init__.py:26: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (hashtable as _hashtable,
# /home/joannelam/Projects/my_project/lib/python2.7/site-packages/pandas/__init__.py:26: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
# ...

# %%
ppd = PrepareData()
df_train , sale_price = ppd.get_train_data(time_series=True)
df_test, test_id = ppd.get_test_data(time_series=True)

# %%
# sales_price = df[['SalePrice']]
df_train.SalePrice.resample('3M').mean().plot(color='y', legend=True)
df_train.SalePrice.resample('6M').mean().plot(color='g', legend=True)
df_train.SalePrice.resample('M').mean().plot(color='r', legend=True)
plt.savefig("sale_price_trend.jpg", dpi=100)
plt.show()

# %%
df_train.corr()[['SalePrice']].sort_values('SalePrice')
# Out:
#                        SalePrice
# MasVnrType_None        -0.374468
# GarageType_Detchd      -0.354141
# Foundation_CBlock      -0.343263
# MSZoning_RM            -0.288065
# LotShape_Reg           -0.267672
# CentralAir_N           -0.251328
# SaleType_WD            -0.242598
# MSSubClass_30          -0.238640
# RoofStyle_Gable        -0.224744
# Foundation_BrkTil      -0.204117
# Electrical_FuseA       -0.193978
# Neighborhood_OldTown   -0.192189
# Neighborhood_NAmes     -0.188513
# Neighborhood_Edwards   -0.179949
# Exterior1st_MetalSd    -0.167068
# Neighborhood_IDOTRR    -0.164056
# HouseStyle_1.5Fin      -0.163466
# Exterior2nd_MetalSd    -0.162389
# Exterior2nd_Wd Sdng    -0.161800
# Exterior1st_Wd Sdng    -0.158619
# MSSubClass_50          -0.156692
# SaleCondition_Normal   -0.153990
# Neighborhood_BrkSide   -0.143648
# Alley_Grvl             -0.139195
# KitchenAbvGr           -0.135907
# EnclosedPorch          -0.128578
# Neighborhood_Sawyer    -0.128394
# ...

# %%
['Alley_nan' , 'GarageType_nan', 'MasVnrType_nan', 'MiscFeature_nan']
# Out:
# ['Alley_nan', 'GarageType_nan', 'MasVnrType_nan', 'MiscFeature_nan']

# %%
dt = df_train.index

# %%
df_train['date'] = dt

# %%
df_train
# Out:
#             LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# dt
# 2006-01-01     0.195205  0.041319     0.555556        0.625   0.739130
# 2006-01-01     0.167979  0.043745     0.444444        0.625   0.644928
# 2006-01-01     0.095890  0.091594     0.777778        0.500   0.963768
# 2006-01-01     0.332192  0.057978     0.666667        0.500   0.934783
# 2006-01-01     0.195205  0.048354     0.666667        0.500   0.963768
# 2006-01-01     0.270548  0.155881     0.444444        0.500   0.601449
# 2006-01-01     0.167979  0.071836     0.777778        0.625   0.789855
# 2006-01-01     0.229452  0.055271     0.444444        0.375   0.615942
# 2006-01-01     0.167979  0.031882     0.555556        0.500   0.927536
# 2006-01-01     0.133562  0.042581     0.222222        0.375   0.311594
# 2006-02-01     0.167979  0.058599     0.666667        0.500   0.840580
# 2006-02-01     0.219178  0.047559     0.555556        0.625   0.746377
# ...

# %%
df_train[['Foundation_CBlock', 'year']]
# Out:
#             Foundation_CBlock
# dt
# 2006-01-01                1.0
# 2006-01-01                1.0
# 2006-01-01                0.0
# 2006-01-01                0.0
# 2006-01-01                0.0
# 2006-01-01                1.0
# 2006-01-01                1.0
# 2006-01-01                1.0
# 2006-01-01                0.0
# 2006-01-01                0.0
# 2006-02-01                0.0
# 2006-02-01                1.0
# 2006-02-01                0.0
# 2006-02-01                0.0
# 2006-02-01                0.0
# 2006-02-01                0.0
# 2006-02-01                1.0
# 2006-02-01                0.0
# 2006-02-01                0.0
# 2006-03-01                0.0
# 2006-03-01                0.0
# 2006-03-01                0.0
# 2006-03-01                1.0
# 2006-03-01                0.0
# 2006-03-01                0.0
# 2006-03-01                1.0
# 2006-03-01                0.0
# 2006-03-01                1.0
# 2006-03-01                0.0
# 2006-03-01                1.0
# ...

# %%
df_train.sort_values(['Foundation_CBlock', 'Yearb'])[ ['Foundation_CBlock', 'OverallQual', 'SalePrice']]
# Out:
#             Foundation_CBlock  OverallQual  SalePrice
# dt
# 2008-05-01                0.0     0.555556   0.239689
# 2009-09-01                0.0     0.777778   0.308429
# 2007-08-01                0.0     0.333333   0.041105
# 2007-08-01                0.0     0.888889   0.336898
# 2007-08-01                0.0     0.777778   0.377864
# 2009-09-01                0.0     0.666667   0.218164
# 2007-08-01                0.0     0.555556   0.194556
# 2007-08-01                0.0     0.555556   0.180669
# 2007-08-01                0.0     0.555556   0.198028
# 2007-08-01                0.0     0.777778   0.344427
# 2007-08-01                0.0     0.666667   0.339675
# 2007-08-01                0.0     0.666667   0.176503
# 2008-10-01                0.0     0.444444   0.201361
# 2009-06-01                0.0     0.555556   0.180669
# 2007-08-01                0.0     0.555556   0.140397
# 2007-08-01                0.0     0.444444   0.137620
# ...

# %%
df_train.corr()[['Foundation_CBlock']].sort_values('Foundation_CBlock')
# Out:
#                        Foundation_CBlock
# Foundation_PConc               -0.781558
# ExterQual                      -0.469367
# BsmtQual                       -0.461558
# Exterior1st_VinylSd            -0.429859
# OverallQual                    -0.429761
# Exterior2nd_VinylSd            -0.429760
# HeatingQC                      -0.427970
# YearRemodAdd                   -0.409630
# KitchenQual                    -0.400653
# GarageYrBlt                    -0.396280
# FullBath                       -0.382029
# SalePrice                      -0.343263
# GarageCars                     -0.318814
# Foundation_BrkTil              -0.292034
# YearBuilt                      -0.290574
# GarageFinish                   -0.283677
# GrLivArea                      -0.266787
# SaleType_New                   -0.259556
# GarageArea                     -0.254663
# SaleCondition_Partial          -0.253266
# BsmtUnfSF                      -0.245484
# 2ndFlrSF                       -0.237462
# ...
